# %% [markdown]
# # Example Testing

# %% [markdown]
# ## Package

# %% [markdown]
# Declare the package path contained:

# %%
import sys
sys.path.append('ipynb/location/packages')

# %% [markdown]
# ### Graph Visualization

# %% [markdown]
# Source referred:
# [NetworkX](https://networkx.org/documentation/stable/tutorial.html)

# %% [markdown]
# Declaring

# %%
from packages.GraphView import Graph

# %% [markdown]
# Example

# %%
matrix = [
    [0, 1, 0],
    [1, 0, 1],
    [0, 1, 0]
]

G = Graph(matrix)
G.show()

# %% [markdown]
# ### Shortest-path

# %% [markdown]
# Source referred:
# [GeeksforGeeks](https://www.geeksforgeeks.org/python-program-for-dijkstras-shortest-path-algorithm-greedy-algo-7/)

# %% [markdown]
# Declaring

# %%
from packages import ShortestPath

# %% [markdown]
# Example

# %% [markdown]
# Graph parameter

# %%
g = ShortestPath.Graph(9)
g.graph = [[0, 4, 0, 0, 0, 0, 0, 8, 0],
           [4, 0, 8, 0, 0, 0, 0, 11, 0],
           [0, 8, 0, 7, 0, 4, 0, 0, 2],
           [0, 0, 7, 0, 9, 14, 0, 0, 0],
           [0, 0, 0, 9, 0, 10, 0, 0, 0],
           [0, 0, 4, 14, 10, 0, 2, 0, 0],
           [0, 0, 0, 0, 0, 2, 0, 1, 6],
           [8, 11, 0, 0, 0, 0, 1, 0, 7],
           [0, 0, 2, 0, 0, 0, 6, 7, 0]
           ]

# %% [markdown]
# Visualization

# %%
Visualization = Graph(g.graph)
Visualization.show()

# %% [markdown]
# Input 2 point requested

# %%
start = 'D'
end = 'A'

# %% [markdown]
# Execute

# %%
startInput = ord(start) - 65
endInput = ord(end) - 65
path, distance = g.getShortestPath(startInput, endInput)
result = [chr(65 + i) for i in path]
print(result)
print("Total distance:", distance)
# Out:
# ['D', 'C', 'B', 'A']
# Total distance: 19

# %% [markdown]
# ## Bottleneck point

# %% [markdown]
# ### Description

# %% [markdown]
# For $v \in V, \: x = (e, \alpha) \in G$, the bottleneck point $v$ on $e=(v_i,v_j)$ is

# %% [markdown]
# $$
# \alpha l_e + d(v_i, v) = (1-\alpha ) l_e + d(v_j, v)
# $$

# %% [markdown]
# - $BP_e$: Set of all bottleneck points on $e \in E$.
#
# - $BP$: Set of all bottleneck points on $G$.

# %% [markdown]
# ### Example

# %%
graph = [
    [0, 1, 3],
    [1, 0, 2],
    [3, 2, 0]
]

# %%
ShowGraph = Graph(graph)
ShowGraph.show()

# %%
from packages.Point import Local

# %%
a = Local(graph, 3, 0, 2)
print(a.BottleNeck(1))
# Out:
# 0.6666666666666666

# %% [markdown]
# ## Equilibrium point

# %% [markdown]
# ### Description

# %% [markdown]
# For $v_k, v_l \in V, \: v_k \neq v_l, \: x = (e, \alpha) \in G, \: e= (v_u, v_v)$, the equililbrium point is

# %% [markdown]
# $$
# \omega _k (\alpha l_e+ d(v_k, v_u)) = \omega _l ((1-\alpha )l_e + d(v_l, v_v))
# $$

# %% [markdown]
# If $x \in G$
#
# $$
# \omega _k d(v_k, x) = \omega _l d(v_l, x)
# $$

# %% [markdown]
# - $EQ_e$: Set of all equilibrium points on $e \in E$.
#
# - $EQ$: Set of all equilibrium points on $G$.

# %% [markdown]
# ### Example

# %%
graph2 = [
    [0, 2, 0, 6, 0],
    [2, 0, 3, 8, 5],
    [0, 3, 0, 0, 7],
    [6, 8, 0, 0, 9],
    [0, 5, 7, 9, 0]
]

# %%
ShowGraph = Graph(graph2)
ShowGraph.show()

# %%
a = Local(graph2, 5, 1, 4)
print(a.EquiPoint(3, 2))
# Out:
# 0.4

# %%
graph3 = [
    [0, 2, 0, 6, 0, 0, 0, 0, 0, 1],
    [2, 0, 3, 8, 5, 0, 0, 0, 0, 0],
    [0, 3, 0, 0, 7, 4, 0, 0, 0, 0],
    [6, 8, 0, 0, 9, 0, 3, 0, 0, 0],
    [0, 5, 7, 9, 0, 0, 0, 2, 0, 0],
    [0, 0, 4, 0, 0, 0, 1, 6, 0, 0],
    [0, 0, 0, 3, 0, 1, 0, 0, 8, 0],
    [0, 0, 0, 0, 2, 6, 0, 0, 5, 3],
    [0, 0, 0, 0, 0, 0, 8, 5, 0, 7],
    [1, 0, 0, 0, 0, 0, 0, 3, 7, 0]
]

# %%
ShowGraph = Graph(graph3)
ShowGraph.show()

# %%
a = Local(graph3, 10, 0, 6)
print(a.EquiPoint(1, 5))
# Out:
# 0.4444444444444444

# %% [markdown]
# ## Local center

# %% [markdown]
# ### Description

# %% [markdown]
# For $e \in E, \: e = (v_i, v_j)$, the local center on $e$ is

# %% [markdown]
# $$
# \arg \underset{x \in e}{\min} f(x) = \arg \min \{ \underset{x \in EQ_e}{\min} f(x), f(v_i), f(v_j) \}
# $$

# %% [markdown]
# ### Bounded value

# %%
graph4 = [
    [0, 4, 3, 1, 2],
    [4, 0, 2, 4, 5],
    [3, 2, 0, 2, 3],
    [1, 4, 2, 0, 1],
    [2, 5, 3, 1, 0]
]
ShowGraph = Graph(graph4)
ShowGraph.show()

# %% [markdown]
# Upper bound $f(v_i)$

# %%
from packages.Point import LocalMinima

# %%
a = LocalMinima(graph4, 5, 0, 1)

print(
    a.upperlm(1),
    a.upperlm(4),
    a.upperlm(2),
    a.upperlm(0)
)
# Out:
# -12 -7 -10 -8

# %%
print(a.BoundedValue(x='upper'))
# Out:
# 0

# %% [markdown]
# Lower bound $f(v_j)$

# %%
print(
    a.lowerlm(1),
    a.lowerlm(4),
    a.lowerlm(2),
    a.lowerlm(3)
)
# Out:
# 4 2 3 1

# %%
print(a.BoundedValue(x='lower'))
# Out:
# 4

# %% [markdown]
# ### Interval value

# %% [markdown]
# $$
# \underset{x \in EQ_e}{\min} f(x)
# $$

# %% [markdown]
# The local minima on segment (A, D) (Not included lower and upper bound)

# %%
eg = LocalMinima(graph4, 5, 0, 1)

min_val, min_x = eg.IntervalValue()
print(min_x)
print(min_val)
# Out:
# 0.75
# 6.0

# %% [markdown]
# Output value

# %%
eg.LocalMinima()
# Out:
# 0

# %% [markdown]
# ## Global center *[In progress...]]*

# %%
from packages.Point import GlobalCenter
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 from packages.Point import GlobalCenter
#
# ImportError: cannot import name 'GlobalCenter' from 'packages.Point' (/Users/chibangnguyen/Documents/thuhoach.nckh/ipynb/location/packages/Point.py)

# %%
Global = [
    [0, 4, 3, 1, 2],
    [4, 0, 2, 4, 5],
    [3, 2, 0, 2, 3],
    [1, 4, 2, 0, 1],
    [2, 5, 3, 1, 0]
]
ShowGraph = Graph(Global)
ShowGraph.show()

# %%
rs = GlobalCenter(Global, 5)

# rs.

rs.GlobalSearch()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 rs = GlobalCenter(Global, 5)
#       3 # rs.
#       5 rs.GlobalSearch()
#
# NameError: name 'GlobalCenter' is not defined
