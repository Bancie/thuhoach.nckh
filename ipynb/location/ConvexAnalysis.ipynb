# %% [markdown]
# # Piecewise linear function

# %% [markdown]
# ## Upper Envelope

# %% [markdown]
# $$
# U(x) = \max \{ f_1(x), f_2(x), f_3(x) \}
# $$

# %%
# %pip install numpy
# %pip install matplotlib
# %pip install itertools
# Out:
# Requirement already satisfied: numpy in /Users/chibangnguyen/Documents/thuhoach.nckh/venv/lib/python3.12/site-packages (2.1.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /Users/chibangnguyen/Documents/thuhoach.nckh/venv/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/chibangnguyen/Documents/thuhoach.nckh/venv/lib/python3.12/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/chibangnguyen/Documents/thuhoach.nckh/venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/chibangnguyen/Documents/thuhoach.nckh/venv/lib/python3.12/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/chibangnguyen/Documents/thuhoach.nckh/venv/lib/python3.12/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /Users/chibangnguyen/Documents/thuhoach.nckh/venv/lib/python3.12/site-packages (from matplotlib) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in /Users/chibangnguyen/Documents/thuhoach.nckh/venv/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/chibangnguyen/Documents/thuhoach.nckh/venv/lib/python3.12/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/chibangnguyen/Documents/thuhoach.nckh/venv/lib/python3.12/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/chibangnguyen/Documents/thuhoach.nckh/venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/chibangnguyen/Documents/thuhoach.nckh/venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement itertools (from versions: none)
# ERROR: No matching distribution found for itertools
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.path.append('ipynb/location/packages')

# %%
from packages.Convex import FunctionPlotter
import numpy as np
import matplotlib.pyplot as plt
from itertools import combinations

# %%
def f1(x):
    return x

def f2(x):
    return -x + 4

def f3(x):
    return x+3

# %%
plotter = FunctionPlotter(0, 10, 100)
plotter.add_function(f1, "x")
plotter.add_function(f2, "-x+4")
plotter.add_function(f3, "x+3")
plotter.plot()

# %% [markdown]
# $$
# U_{\text{(Function Plot)}}(x) = \max \{x, -x+4, x+3 \}
# $$

# %%
lines = [
    lambda x: x,
    lambda x: -x + 4,
    lambda x: x + 3
]

def upper_envelope(x):
    return max(f(x) for f in lines)

# %%
x_vals = np.linspace(-1, 5, 500)
y_vals = [upper_envelope(x) for x in x_vals]

plt.plot(x_vals, y_vals, label='Upper Envelope U(x)', color='black', linestyle='--')
plt.legend()
plt.grid(True)
plt.title("Upper Envelope of 3 Functions")
plt.xlabel("x")
plt.ylabel("U(x)")
plt.show()

# %%
def intersect(f1, f2):
    a1 = f1(1) - f1(0)
    b1 = f1(0)
    a2 = f2(1) - f2(0)
    b2 = f2(0)
    if a1 == a2:
        return None
    return (b2 - b1) / (a1 - a2)

xs = []
for f1, f2 in combinations(lines, 2):
    x = intersect(f1, f2)
    if x is not None:
        xs.append(x)

# You may want to restrict the domain or extend range
candidates = xs + [-100, 100]

min_val = float('inf')
min_x = None
for x in candidates:
    val = upper_envelope(x)
    if val < min_val:
        min_val = val
        min_x = x

print(f"Minimum of upper envelope is {min_val} at x = {min_x}")
# Out:
# Minimum of upper envelope is 3.5 at x = 0.5

# %% [markdown]
# ## Package testing

# %%
from packages.Convex import LocalMinima

# %%
eg = LocalMinima()

eg.add_line(lambda x: x)
eg.add_line(lambda x: -x+4)
eg.add_line(lambda x: x+3)

min_val, min_x = eg.showVal(-100, 100)
print(min_x)
print(min_val)
# Out:
# 0.5
# 3.5
