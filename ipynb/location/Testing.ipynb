# %% [markdown]
# # Piecewise linear function

# %% [markdown]
# ## Graph

# %%
import sys
sys.path.append('ipynb/location/packages')

# %%
from packages.Convex import FunctionPlotter

# %%
# Example usage
def f1(x): return np.sin(x)
def f2(x): return np.cos(x)
def f3(x): return x**2

# %%
plotter = FunctionPlotter(-10, 10, 400)
plotter.add_function(f1, "sin(x)")
plotter.add_function(f2, "cos(x)")
plotter.add_function(f3, "x²")
plotter.plot("Multiple Functions")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 plotter = FunctionPlotter(-10, 10, 400)
#       2 plotter.add_function(f1, "sin(x)")
#       3 plotter.add_function(f2, "cos(x)")
#
# TypeError: FunctionPlotter.__init__() takes from 1 to 3 positional arguments but 4 were given
